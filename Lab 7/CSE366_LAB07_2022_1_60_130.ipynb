# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !dir -a C:\Users\azmi0\Downloads\Compressed\caltech-101\caltech-101\101_ObjectCategories\101_ObjectCategories
# Out:
#  Volume in drive C is Windows-SSD
#  Volume Serial Number is ACF0-6E72
#
#  Directory of c:\Users\azmi0\Downloads
#
#
#  Directory of C:\Users\azmi0\Downloads\Compressed\caltech-101\caltech-101\101_ObjectCategories\101_ObjectCategories
#
# 11/09/2004  12:31 PM    <DIR>          .
# 01/07/2025  09:07 PM    <DIR>          ..
# 11/09/2004  12:28 PM    <DIR>          accordion
# 11/09/2004  12:29 PM    <DIR>          airplanes
# 11/09/2004  12:29 PM    <DIR>          anchor
# 11/09/2004  12:29 PM    <DIR>          ant
# 11/09/2004  12:28 PM    <DIR>          BACKGROUND_Google
# 11/09/2004  12:29 PM    <DIR>          barrel
# 11/09/2004  12:29 PM    <DIR>          bass
# 11/09/2004  12:29 PM    <DIR>          beaver
# 11/09/2004  12:29 PM    <DIR>          binocular
# 11/09/2004  12:29 PM    <DIR>          bonsai
# 11/09/2004  12:29 PM    <DIR>          brain
# 11/09/2004  12:29 PM    <DIR>          brontosaurus
# 11/09/2004  12:29 PM    <DIR>          buddha
# 11/09/2004  12:29 PM    <DIR>          butterfly
# 11/09/2004  12:29 PM    <DIR>          camera
# 11/09/2004  12:29 PM    <DIR>          cannon
# 11/09/2004  12:29 PM    <DIR>          car_side
# 11/09/2004  12:29 PM    <DIR>          ceiling_fan
# 11/09/2004  12:29 PM    <DIR>          cellphone
# 11/09/2004  12:29 PM    <DIR>          chair
# 11/09/2004  12:29 PM    <DIR>          chandelier
# 11/09/2004  12:31 PM    <DIR>          cougar_body
# 11/09/2004  12:29 PM    <DIR>          cougar_face
# 11/09/2004  12:29 PM    <DIR>          crab
# 11/09/2004  12:29 PM    <DIR>          crayfish
# 11/09/2004  12:29 PM    <DIR>          crocodile
# 11/09/2004  12:29 PM    <DIR>          crocodile_head
# 11/09/2004  12:29 PM    <DIR>          cup
# 11/09/2004  12:29 PM    <DIR>          dalmatian
# 11/09/2004  12:29 PM    <DIR>          dollar_bill
# 11/09/2004  12:29 PM    <DIR>          dolphin
# 11/09/2004  12:29 PM    <DIR>          dragonfly
# 11/09/2004  12:29 PM    <DIR>          electric_guitar
# 11/09/2004  12:29 PM    <DIR>          elephant
# 11/09/2004  12:29 PM    <DIR>          emu
# 11/09/2004  12:29 PM    <DIR>          euphonium
# 11/09/2004  12:29 PM    <DIR>          ewer
# 11/09/2004  12:28 PM    <DIR>          Faces
# 11/09/2004  12:28 PM    <DIR>          Faces_easy
# 11/09/2004  12:29 PM    <DIR>          ferry
# 11/09/2004  12:29 PM    <DIR>          flamingo
# 11/09/2004  12:29 PM    <DIR>          flamingo_head
# 11/09/2004  12:29 PM    <DIR>          garfield
# 11/09/2004  12:29 PM    <DIR>          gerenuk
# 11/09/2004  12:29 PM    <DIR>          gramophone
# 11/09/2004  12:29 PM    <DIR>          grand_piano
# 11/09/2004  12:29 PM    <DIR>          hawksbill
# 11/09/2004  12:29 PM    <DIR>          headphone
# 11/09/2004  12:30 PM    <DIR>          hedgehog
# 11/09/2004  12:30 PM    <DIR>          helicopter
# 11/09/2004  12:30 PM    <DIR>          ibis
# 11/09/2004  12:30 PM    <DIR>          inline_skate
# 11/09/2004  12:30 PM    <DIR>          joshua_tree
# 11/09/2004  12:30 PM    <DIR>          kangaroo
# 11/09/2004  12:30 PM    <DIR>          ketch
# 11/09/2004  12:30 PM    <DIR>          lamp
# 11/09/2004  12:30 PM    <DIR>          laptop
# 11/09/2004  12:28 PM    <DIR>          Leopards
# 11/09/2004  12:30 PM    <DIR>          llama
# 11/09/2004  12:30 PM    <DIR>          lobster
# 11/09/2004  12:30 PM    <DIR>          lotus
# 11/09/2004  12:30 PM    <DIR>          mandolin
# 11/09/2004  12:30 PM    <DIR>          mayfly
# 11/09/2004  12:30 PM    <DIR>          menorah
# 11/09/2004  12:30 PM    <DIR>          metronome
# 11/09/2004  12:30 PM    <DIR>          minaret
# 11/09/2004  12:28 PM    <DIR>          Motorbikes
# 11/09/2004  12:30 PM    <DIR>          nautilus
# 11/09/2004  12:30 PM    <DIR>          octopus
# 11/09/2004  12:30 PM    <DIR>          okapi
# 11/09/2004  12:30 PM    <DIR>          pagoda
# 11/09/2004  12:30 PM    <DIR>          panda
# 11/09/2004  12:30 PM    <DIR>          pigeon
# 11/09/2004  12:30 PM    <DIR>          pizza
# 11/09/2004  12:30 PM    <DIR>          platypus
# 11/09/2004  12:30 PM    <DIR>          pyramid
# 11/09/2004  12:30 PM    <DIR>          revolver
# 11/09/2004  12:30 PM    <DIR>          rhino
# 11/09/2004  12:30 PM    <DIR>          rooster
# 11/09/2004  12:30 PM    <DIR>          saxophone
# 11/09/2004  12:30 PM    <DIR>          schooner
# 11/09/2004  12:30 PM    <DIR>          scissors
# 11/09/2004  12:30 PM    <DIR>          scorpion
# 11/09/2004  12:30 PM    <DIR>          sea_horse
# 11/09/2004  12:30 PM    <DIR>          snoopy
# 11/09/2004  12:30 PM    <DIR>          soccer_ball
# 11/09/2004  12:30 PM    <DIR>          stapler
# 11/09/2004  12:30 PM    <DIR>          starfish
# 11/09/2004  12:30 PM    <DIR>          stegosaurus
# 11/09/2004  12:30 PM    <DIR>          stop_sign
# 11/09/2004  12:30 PM    <DIR>          strawberry
# 11/09/2004  12:30 PM    <DIR>          sunflower
# 11/09/2004  12:30 PM    <DIR>          tick
# 11/09/2004  12:30 PM    <DIR>          trilobite
# 11/09/2004  12:30 PM    <DIR>          umbrella
# 11/09/2004  12:30 PM    <DIR>          watch
# 11/09/2004  12:30 PM    <DIR>          water_lilly
# 11/09/2004  12:30 PM    <DIR>          wheelchair
# 11/09/2004  12:30 PM    <DIR>          wild_cat
# 11/09/2004  12:30 PM    <DIR>          windsor_chair
# 11/09/2004  12:30 PM    <DIR>          wrench
# 11/09/2004  12:31 PM    <DIR>          yin_yang
#                0 File(s)              0 bytes
#              104 Dir(s)  101,782,765,568 bytes free
# File Not Found

# %% [markdown]
# **Load Dataset**

# %%
# %pip install torch torchvision
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: torch in c:\users\azmi0\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (2.5.1)
# Requirement already satisfied: torchvision in c:\users\azmi0\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (0.20.1)
# Requirement already satisfied: filelock in c:\users\azmi0\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from torch) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\azmi0\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from torch) (4.12.2)
# Requirement already satisfied: networkx in c:\users\azmi0\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in c:\users\azmi0\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from torch) (3.1.5)
# Requirement already satisfied: fsspec in c:\users\azmi0\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from torch) (2024.12.0)
# Requirement already satisfied: setuptools in c:\users\azmi0\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from torch) (75.7.0)
# Requirement already satisfied: sympy==1.13.1 in c:\users\azmi0\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\azmi0\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: numpy in c:\users\azmi0\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from torchvision) (2.2.1)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\users\azmi0\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from torchvision) (11.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\azmi0\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from jinja2->torch) (3.0.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install --upgrade torch
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: torch in c:\users\azmi0\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (2.5.1)
# Requirement already satisfied: filelock in c:\users\azmi0\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from torch) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\azmi0\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from torch) (4.12.2)
# Requirement already satisfied: networkx in c:\users\azmi0\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in c:\users\azmi0\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from torch) (3.1.5)
# Requirement already satisfied: fsspec in c:\users\azmi0\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from torch) (2024.12.0)
# Requirement already satisfied: setuptools in c:\users\azmi0\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from torch) (75.7.0)
# Requirement already satisfied: sympy==1.13.1 in c:\users\azmi0\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\azmi0\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\azmi0\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from jinja2->torch) (3.0.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
from torchvision import datasets, transforms

transform = transforms.Compose([
	transforms.Resize((128, 128)),
	transforms.RandomHorizontalFlip(),
	transforms.RandomVerticalFlip(),
	transforms.RandomRotation(30),
	transforms.ColorJitter(brightness=0.4, contrast=0.4, saturation=0.4, hue=0.1),
	transforms.RandomAffine(degrees=15, translate=(0.1, 0.1), scale=(0.9, 1.1)),
	transforms.RandomGrayscale(p=0.2),
	transforms.ToTensor(),
	transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

dataset = datasets.ImageFolder(
	root=r'C:\Users\azmi0\Downloads\Compressed\caltech-101\caltech-101\101_ObjectCategories\101_ObjectCategories',
	transform=transform
)

# %% [markdown]
# **Split Dataset**

# %%
from torch.utils.data import random_split
train_size = int(0.8 * len(dataset))
val_size = int(0.1 * len(dataset))
test_size = len(dataset) - train_size - val_size
train_data, val_data, test_data = random_split(dataset, [train_size,
val_size, test_size])

# %% [markdown]
# **Data Loaders**

# %%
from torch.utils.data import DataLoader
train_loader = DataLoader(train_data, batch_size=32, shuffle=True)
val_loader = DataLoader(val_data, batch_size=32)
test_loader = DataLoader(test_data, batch_size=32)

# %% [markdown]
# **Using Pre-trained Models**

# %% [markdown]
# **VGG19 Model**

# %%
import torch
from torchvision.models import vgg19
model = vgg19(pretrained=True)
model.classifier[6] = torch.nn.Linear(4096, 101) # Adjust the final layer
# Out:
# C:\Users\azmi0\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\torchvision\models\_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# C:\Users\azmi0\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG19_Weights.IMAGENET1K_V1`. You can also use `weights=VGG19_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %% [markdown]
# **ResNet50 Model**

# %%
from torchvision.models import resnet50
model = resnet50(pretrained=True)

model.fc = torch.nn.Linear(2048, 101) # Adjust the final layer for 101
# Out:
# C:\Users\azmi0\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %% [markdown]
# **EfficientNet (EfficientNet-B0)**

# %%
from torchvision.models import efficientnet_b0
model = efficientnet_b0(pretrained=True)
model.classifier[1] = torch.nn.Linear(1280, 101) # Adjust the final layer
# Out:
# C:\Users\azmi0\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\torchvision\models\_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=EfficientNet_B0_Weights.IMAGENET1K_V1`. You can also use `weights=EfficientNet_B0_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)

# %% [markdown]
# **Part 4: Training the Model**

# %% [markdown]
# Define Loss and Optimizer

# %%
import torch.optim as optim
criterion = torch.nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

# %% [markdown]
# **Train the Molde**

# %%
# %pip install torch torchvision torchaudio --extra-index-url https://download.pytorch.org/whl/cu117
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Looking in indexes: https://pypi.org/simple, https://download.pytorch.org/whl/cu117
# Requirement already satisfied: torch in c:\users\azmi0\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (2.5.1)
# Requirement already satisfied: torchvision in c:\users\azmi0\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (0.20.1)
# Requirement already satisfied: torchaudio in c:\users\azmi0\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (2.5.1)
# Requirement already satisfied: filelock in c:\users\azmi0\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from torch) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\azmi0\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from torch) (4.12.2)
# Requirement already satisfied: networkx in c:\users\azmi0\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in c:\users\azmi0\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from torch) (3.1.5)
# Requirement already satisfied: fsspec in c:\users\azmi0\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from torch) (2024.12.0)
# Requirement already satisfied: setuptools in c:\users\azmi0\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from torch) (75.7.0)
# Requirement already satisfied: sympy==1.13.1 in c:\users\azmi0\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\azmi0\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: numpy in c:\users\azmi0\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from torchvision) (2.2.1)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in c:\users\azmi0\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from torchvision) (11.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\azmi0\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from jinja2->torch) (3.0.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
import torch

# Check if CUDA is available and set the device accordingly
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Move the model to the selected device
model.to(device)

# Example: Move a tensor to the selected device
tensor = torch.randn(10).to(device)

print(f"Using device: {device}")
# Out:
# Using device: cpu

# %%
for epoch in range(10):
	model.train()
	for images, labels in train_loader:
		images, labels = images.to(device), labels.to(device)
		labels = labels % 101
  # Ensure labels are within the correct range
		optimizer.zero_grad()
		outputs = model(images)
		loss = criterion(outputs, labels)
		loss.backward()
		optimizer.step()

# %% [markdown]
# **Validate the Model**

# %%
model.eval()
with torch.no_grad():
	for images, labels in val_loader:
		outputs = model(images)
		# Compute validation metrics

# %% [markdown]
# **Parameter Tuning with Grid Search**

# %%
# %pip install scikit-learn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: scikit-learn in c:\users\azmi0\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (1.6.0)
# Requirement already satisfied: numpy>=1.19.5 in c:\users\azmi0\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from scikit-learn) (2.2.1)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\azmi0\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from scikit-learn) (1.15.0)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\azmi0\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\azmi0\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from scikit-learn) (3.5.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from sklearn.model_selection import ParameterGrid

param_grid = {
	'lr': [0.1, 0.01, 0.001],
	'batch_size': [16, 32, 64]
}

best_params = None
best_accuracy = 0

for params in ParameterGrid(param_grid):
	optimizer = optim.Adam(model.parameters(), lr=params['lr'])
	train_loader = DataLoader(train_data, batch_size=params['batch_size'], shuffle=True)

	# Perform training and validation here
	# For demonstration, let's assume accuracy is calculated and assigned
	accuracy = 0.85  # Replace with actual accuracy calculation

	if accuracy > best_accuracy:
		best_accuracy = accuracy
		best_params = params

print(f"Best Params: {best_params}")
# Out:
# Best Params: {'batch_size': 16, 'lr': 0.1}

# %% [markdown]
# **Part 5: Evaluating the Model**

# %% [markdown]
# Evaluate on Test Data

# %%
model.eval()

with torch.no_grad():
	for images, labels in test_loader:
		outputs = model(images)
		# Compute test metrics

# %% [markdown]
# **Confusion Matrix**

# %%
from sklearn.metrics import confusion_matrix
y_pred = []
y_true = []
with torch.no_grad():
	for images, labels in test_loader:
		outputs = model(images)
		_, preds = torch.max(outputs, 1)
		y_pred.extend(preds.numpy())
		y_true.extend(labels.numpy())
cm = confusion_matrix(y_true, y_pred)
print(cm)
# Out:
# [[22  0  0 ...  0  0  0]
#  [ 0 47  1 ...  0  0  0]
#  [ 0  1 30 ...  0  0  0]
#  ...
#  [ 0  0  0 ...  6  0  0]
#  [ 0  0  0 ...  0  1  0]
#  [ 7  0  0 ...  0  0  0]]

# %% [markdown]
# **Classification Report**

# %%
class_names = dataset.classes  # Define class_names based on the dataset

# Ensure the number of class names matches the number of unique labels in y_true
unique_labels = sorted(set(y_true))
adjusted_class_names = [class_names[i] for i in unique_labels]

from sklearn.metrics import classification_report
print(classification_report(y_true, y_pred, labels=unique_labels, target_names=adjusted_class_names))
# Out:
#                    precision    recall  f1-score   support
#
# BACKGROUND_Google       0.51      0.54      0.52        41
#             Faces       0.98      0.98      0.98        48
#        Faces_easy       0.97      0.97      0.97        31
#          Leopards       1.00      0.96      0.98        26
#        Motorbikes       0.99      0.99      0.99        82
#         accordion       0.90      0.90      0.90        10
#         airplanes       0.99      0.99      0.99        69
#            anchor       0.60      0.60      0.60         5
#               ant       0.33      0.50      0.40         2
#              bass       0.33      1.00      0.50         2
#            beaver       1.00      0.60      0.75         5
#         binocular       1.00      1.00      1.00         2
#            bonsai       0.80      0.62      0.70        13
#             brain       0.85      0.85      0.85        13
#      brontosaurus       0.25      0.50      0.33         4
#            buddha       1.00      0.85      0.92        13
#         butterfly       0.70      0.70      0.70        10
#            camera       1.00      0.67      0.80         6
#            cannon       1.00      0.44      0.62         9
#          car_side       1.00      0.91      0.95        11
#       ceiling_fan       0.89      0.89      0.89         9
#         cellphone       1.00      1.00      1.00         8
#             chair       0.43      0.33      0.38         9
#        chandelier       0.67      0.80      0.73        10
#       cougar_body       1.00      0.57      0.73         7
#       cougar_face       0.89      0.89      0.89         9
#              crab       0.33      0.67      0.44         3
#          crayfish       1.00      0.33      0.50         6
#         crocodile       0.20      1.00      0.33         1
#    crocodile_head       0.33      0.33      0.33         3
#               cup       0.67      0.86      0.75         7
#         dalmatian       0.71      1.00      0.83         5
#       dollar_bill       0.89      0.89      0.89         9
#           dolphin       0.78      0.78      0.78         9
#         dragonfly       1.00      0.88      0.93         8
#   electric_guitar       0.71      0.83      0.77         6
#          elephant       0.50      0.67      0.57         6
#               emu       0.62      0.73      0.67        11
#         euphonium       1.00      0.55      0.71        11
#              ewer       0.67      0.89      0.76         9
#             ferry       1.00      1.00      1.00         5
#          flamingo       0.73      0.80      0.76        10
#     flamingo_head       0.40      0.67      0.50         3
#          garfield       0.67      0.67      0.67         3
#           gerenuk       1.00      1.00      1.00         3
#        gramophone       0.60      0.43      0.50         7
#       grand_piano       0.85      1.00      0.92        11
#         hawksbill       1.00      0.73      0.84        11
#         headphone       0.57      0.80      0.67         5
#          hedgehog       0.89      0.73      0.80        11
#        helicopter       0.50      1.00      0.67         5
#              ibis       0.71      0.31      0.43        16
#       joshua_tree       0.73      0.92      0.81        12
#          kangaroo       0.64      0.70      0.67        10
#             ketch       0.73      1.00      0.84         8
#              lamp       0.67      0.50      0.57         4
#            laptop       1.00      1.00      1.00        15
#             llama       0.33      0.50      0.40         8
#           lobster       1.00      0.50      0.67         4
#             lotus       0.50      0.25      0.33         4
#          mandolin       0.00      0.00      0.00         1
#            mayfly       0.00      0.00      0.00         3
#           menorah       0.88      1.00      0.93         7
#         metronome       1.00      0.83      0.91         6
#           minaret       0.75      1.00      0.86         3
#          nautilus       1.00      1.00      1.00         3
#           octopus       0.00      0.00      0.00         1
#             okapi       1.00      0.67      0.80         6
#            pagoda       0.83      1.00      0.91         5
#             panda       0.75      0.86      0.80         7
#            pigeon       0.25      0.50      0.33         2
#             pizza       0.33      0.50      0.40         2
#          platypus       1.00      0.20      0.33         5
#           pyramid       0.57      1.00      0.73         4
#          revolver       0.92      0.92      0.92        12
#             rhino       0.50      0.25      0.33         4
#           rooster       0.67      1.00      0.80         2
#         saxophone       0.60      1.00      0.75         3
#          schooner       1.00      0.71      0.83        14
#          scissors       1.00      1.00      1.00         5
#          scorpion       0.67      0.75      0.71         8
#         sea_horse       0.25      0.20      0.22         5
#            snoopy       1.00      1.00      1.00         1
#       soccer_ball       0.75      1.00      0.86         3
#           stapler       0.80      0.80      0.80         5
#          starfish       0.86      0.67      0.75         9
#       stegosaurus       0.83      1.00      0.91         5
#         stop_sign       1.00      1.00      1.00         6
#        strawberry       0.00      0.00      0.00         1
#         sunflower       1.00      1.00      1.00         9
#              tick       0.75      0.75      0.75         4
#         trilobite       0.89      0.89      0.89         9
#          umbrella       0.75      0.60      0.67         5
#             watch       1.00      0.94      0.97        16
#        wheelchair       0.64      0.78      0.70         9
#          wild_cat       0.33      1.00      0.50         2
#     windsor_chair       1.00      0.60      0.75        10
#            wrench       0.33      0.33      0.33         3
#          yin_yang       0.00      0.00      0.00         7
#
#         micro avg       0.80      0.80      0.80       915
#         macro avg       0.72      0.72      0.69       915
#      weighted avg       0.83      0.80      0.80       915
# C:\Users\azmi0\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\azmi0\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\azmi0\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %% [markdown]
# **Top-k Accuracy**

# %%
def top_k_accuracy(output, target, k=5):
	with torch.no_grad():
		max_k_preds = torch.topk(output, k, dim=1).indices
		correct = max_k_preds.eq(target.view(-1, 1).expand_as(max_k_preds))
		return correct.any(dim=1).float().mean().item()

# %% [markdown]
# **Per-Class Accuracy**

# %%
per_class_accuracy = cm.diagonal() / cm.sum(axis=1)
for i, acc in enumerate(per_class_accuracy):
	print(f"Class {class_names[i]} Accuracy: {acc:.2f}")
# Out:
# Class BACKGROUND_Google Accuracy: 0.54
# Class Faces Accuracy: 0.98
# Class Faces_easy Accuracy: 0.97
# Class Leopards Accuracy: 0.96
# Class Motorbikes Accuracy: 0.99
# Class accordion Accuracy: 0.90
# Class airplanes Accuracy: 0.99
# Class anchor Accuracy: 0.60
# Class ant Accuracy: 0.50
# Class barrel Accuracy: 1.00
# Class bass Accuracy: 0.60
# Class beaver Accuracy: 1.00
# Class binocular Accuracy: 0.62
# Class bonsai Accuracy: 0.85
# Class brain Accuracy: 0.50
# Class brontosaurus Accuracy: 0.85
# Class buddha Accuracy: 0.70
# Class butterfly Accuracy: 0.67
# Class camera Accuracy: 0.44
# Class cannon Accuracy: 0.91
# Class car_side Accuracy: 0.89
# Class ceiling_fan Accuracy: 1.00
# Class cellphone Accuracy: 0.33
# Class chair Accuracy: 0.80
# Class chandelier Accuracy: 0.57
# Class cougar_body Accuracy: 0.89
# Class cougar_face Accuracy: 0.67
# Class crab Accuracy: 0.33
# Class crayfish Accuracy: 1.00
# Class crocodile Accuracy: 0.33
# Class crocodile_head Accuracy: 0.86
# Class cup Accuracy: 1.00
# Class dalmatian Accuracy: 0.89
# Class dollar_bill Accuracy: 0.78
# Class dolphin Accuracy: 0.88
# Class dragonfly Accuracy: 0.83
# Class electric_guitar Accuracy: 0.67
# Class elephant Accuracy: 0.73
# Class emu Accuracy: 0.55
# Class euphonium Accuracy: 0.89
# Class ewer Accuracy: 1.00
# Class ferry Accuracy: 0.80
# Class flamingo Accuracy: 0.67
# Class flamingo_head Accuracy: 0.67
# Class garfield Accuracy: 1.00
# Class gerenuk Accuracy: 0.43
# Class gramophone Accuracy: 1.00
# Class grand_piano Accuracy: 0.73
# Class hawksbill Accuracy: 0.80
# Class headphone Accuracy: 0.73
# Class hedgehog Accuracy: 1.00
# Class helicopter Accuracy: 0.31
# Class ibis Accuracy: nan
# Class inline_skate Accuracy: 0.92
# Class joshua_tree Accuracy: 0.70
# Class kangaroo Accuracy: 1.00
# Class ketch Accuracy: 0.50
# Class lamp Accuracy: 1.00
# Class laptop Accuracy: 0.50
# Class llama Accuracy: 0.50
# Class lobster Accuracy: 0.25
# Class lotus Accuracy: 0.00
# Class mandolin Accuracy: 0.00
# Class mayfly Accuracy: 1.00
# Class menorah Accuracy: 0.83
# Class metronome Accuracy: 1.00
# Class minaret Accuracy: 1.00
# Class nautilus Accuracy: 0.00
# Class octopus Accuracy: 0.67
# Class okapi Accuracy: 1.00
# Class pagoda Accuracy: 0.86
# Class panda Accuracy: 0.50
# Class pigeon Accuracy: 0.50
# Class pizza Accuracy: 0.20
# Class platypus Accuracy: 1.00
# Class pyramid Accuracy: 0.92
# Class revolver Accuracy: 0.25
# Class rhino Accuracy: 1.00
# Class rooster Accuracy: 1.00
# Class saxophone Accuracy: 0.71
# Class schooner Accuracy: 1.00
# Class scissors Accuracy: 0.75
# Class scorpion Accuracy: 0.20
# Class sea_horse Accuracy: 1.00
# Class snoopy Accuracy: 1.00
# Class soccer_ball Accuracy: 0.80
# Class stapler Accuracy: 0.67
# Class starfish Accuracy: 1.00
# Class stegosaurus Accuracy: 1.00
# Class stop_sign Accuracy: 0.00
# Class strawberry Accuracy: 1.00
# Class sunflower Accuracy: 0.75
# Class tick Accuracy: 0.89
# Class trilobite Accuracy: 0.60
# Class umbrella Accuracy: 0.94
# Class watch Accuracy: nan
# Class water_lilly Accuracy: 0.78
# Class wheelchair Accuracy: 1.00
# Class wild_cat Accuracy: 0.60
# Class windsor_chair Accuracy: 0.33
# Class wrench Accuracy: 0.00
# C:\Users\azmi0\AppData\Local\Temp\ipykernel_18916\2607755435.py:1: RuntimeWarning: invalid value encountered in divide
#   per_class_accuracy = cm.diagonal() / cm.sum(axis=1)

# %% [markdown]
# **t-SNE Visualization**

# %%
# %pip install matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: matplotlib in c:\users\azmi0\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\azmi0\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\azmi0\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\azmi0\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\azmi0\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in c:\users\azmi0\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib) (2.2.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\azmi0\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\azmi0\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\azmi0\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\azmi0\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\azmi0\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt

features = []
labels_list = []
model.eval()
with torch.no_grad():
	for images, labels in test_loader:
		output = model(images)
		features.append(output)
		labels_list.append(labels)

features = torch.cat(features).numpy()
labels_list = torch.cat(labels_list).numpy()
tsne = TSNE(n_components=2, random_state=42)
reduced_features = tsne.fit_transform(features)
plt.scatter(reduced_features[:, 0], reduced_features[:, 1], c=labels_list, cmap='tab10')
plt.colorbar()
plt.show()

# %% [markdown]
# **Part 6: Explainable AI (XAI) with Grad-CAM**

# %% [markdown]
# **Install Grad-CAM Library**

# %%
# %pip install grad-cam
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: grad-cam in c:\users\azmi0\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (1.5.4)
# Requirement already satisfied: numpy in c:\users\azmi0\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from grad-cam) (2.2.1)
# Requirement already satisfied: Pillow in c:\users\azmi0\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from grad-cam) (11.1.0)
# Requirement already satisfied: torch>=1.7.1 in c:\users\azmi0\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from grad-cam) (2.5.1)
# Requirement already satisfied: torchvision>=0.8.2 in c:\users\azmi0\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from grad-cam) (0.20.1)
# Requirement already satisfied: ttach in c:\users\azmi0\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from grad-cam) (0.0.3)
# Requirement already satisfied: tqdm in c:\users\azmi0\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from grad-cam) (4.67.1)
# Requirement already satisfied: opencv-python in c:\users\azmi0\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from grad-cam) (4.10.0.84)
# Requirement already satisfied: matplotlib in c:\users\azmi0\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from grad-cam) (3.10.0)
# Requirement already satisfied: scikit-learn in c:\users\azmi0\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from grad-cam) (1.6.0)
# Requirement already satisfied: filelock in c:\users\azmi0\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from torch>=1.7.1->grad-cam) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\azmi0\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from torch>=1.7.1->grad-cam) (4.12.2)
# Requirement already satisfied: networkx in c:\users\azmi0\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from torch>=1.7.1->grad-cam) (3.4.2)
# Requirement already satisfied: jinja2 in c:\users\azmi0\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from torch>=1.7.1->grad-cam) (3.1.5)
# Requirement already satisfied: fsspec in c:\users\azmi0\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from torch>=1.7.1->grad-cam) (2024.12.0)
# Requirement already satisfied: setuptools in c:\users\azmi0\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from torch>=1.7.1->grad-cam) (75.7.0)
# Requirement already satisfied: sympy==1.13.1 in c:\users\azmi0\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from torch>=1.7.1->grad-cam) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\azmi0\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from sympy==1.13.1->torch>=1.7.1->grad-cam) (1.3.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\azmi0\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib->grad-cam) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\azmi0\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib->grad-cam) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\azmi0\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib->grad-cam) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\azmi0\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib->grad-cam) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\azmi0\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib->grad-cam) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\azmi0\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib->grad-cam) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\azmi0\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib->grad-cam) (2.9.0.post0)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\azmi0\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from scikit-learn->grad-cam) (1.15.0)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\azmi0\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from scikit-learn->grad-cam) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\azmi0\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from scikit-learn->grad-cam) (3.5.0)
# Requirement already satisfied: colorama in c:\users\azmi0\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from tqdm->grad-cam) (0.4.6)
# Requirement already satisfied: six>=1.5 in c:\users\azmi0\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from python-dateutil>=2.7->matplotlib->grad-cam) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\azmi0\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from jinja2->torch>=1.7.1->grad-cam) (3.0.2)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# **Apply Grad-CAM**

# %%
from pytorch_grad_cam import GradCAM
from pytorch_grad_cam.utils.image import show_cam_on_image
from pytorch_grad_cam.utils.model_targets import ClassifierOutputTarget
import matplotlib.pyplot as plt

# Adjust based on the model's architecture
# Check model architecture and set target layer
if isinstance(model, torch.nn.Sequential):  # VGG19
    target_layer = model.features[-1]
elif isinstance(model, torch.nn.Module) and hasattr(model, 'layer4'):  # ResNet50
    target_layer = model.layer4[-1]
elif isinstance(model, torch.nn.Module) and hasattr(model, 'features'):  # EfficientNet-B0
    target_layer = model.features[-1]
else:
    raise ValueError("Model architecture not recognized")

# Initialize GradCAM
cam = GradCAM(model=model, target_layers=[target_layer])

# Generate and display CAMs
count = 0
for images, labels in test_loader:
    images, labels = images.to(device), labels.to(device)
    labels = labels % 101  # Ensure labels are within the correct range
    targets = [ClassifierOutputTarget(label.item()) for label in labels]
    grayscale_cam = cam(input_tensor=images, targets=targets)
    for i in range(len(images)):
        if count >= 5:
            break
        image = images[i].permute(1, 2, 0).cpu().numpy()
        image = (image - image.min()) / (image.max() - image.min())  # Normalize to [0, 1]
        cam_image = show_cam_on_image(image, grayscale_cam[i])
        plt.imshow(cam_image)
        plt.show()
        count += 1
    if count >= 5:
        break
